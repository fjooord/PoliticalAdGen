# %%
import os
import glob
import json
import Utils.Chat_GPT_Funcs as GPT
import concurrent.futures
import os
import string

# %%
file_path = "survey_responses_343.json"
with open(file_path, "r") as json_file:
    responses = json.load(json_file)

# %%
responses[0]['survey_responses']['19']
# Out:
# '{\n    "Reasoning": "As someone living in rural Montana, I know that the winters can be long and harsh. Being stuck inside for long periods of time can definitely take a toll on one\'s mental health. As a veterinary assistant, I have seen firsthand the impact that pets can have on their owners\' mental health. Therefore, I believe that more fun indoor activities could help alleviate depression in Montana. It would give people something to look forward to and provide a way to socialize and connect with others, even during the winter months.",\n    "Answer": "Agree"\n}'

# %%
class Question:
    def __init__(self, number, question, possible_responses):
        self.number = number
        self.question = question
        self.possible_responses = possible_responses

    def format_for_gpt(self):
        formatted_question = self.question + '\n'
        formatted_responses = '\n'.join(self.possible_responses)

        return formatted_question + formatted_responses
questions = [
    Question(1, "Do you plan to vote in the 2022 midterm election?", ["Yes", "No", "Neither"]),
    Question(2, "At this point in time, do you approve or disapprove of President Joe Biden’s performance in office?", ["Approve", "Disapprove", "Neither Approve/Disapprove"]),
    Question(3, "Do you approve or disapprove of Biden’s student loan forgiveness plan?", ["Approve", "Disapprove", "Neither Approve/Disapprove"]),
    Question(4, "At this point in time, do you approve or disapprove of the performance of the US Congress?", ["Approve", "Disapprove", "Neither Approve/Disapprove"]),
    Question(5, "When electing the United States president, do you think we should amend the Constitution to allow the candidate who receives the most votes to win, or do you think we should keep the current system where the candidate who wins the Electoral College vote wins?", ["Amend the Constitution", "Keep the current system"]),
    Question(6, "At this point in time, do you approve or disapprove of Governor Greg Gianforte’s job performance?", ["Approve", "Disapprove", "Neither Approve/Disapprove"]),
    Question(7, "Gianforte’s administration recently attempted to implement a rule banning transgender people from changing their designated sex status on their birth certificate. Do you think transgender people should be able to change the sex on their birth certificate?", ["Yes", "No", "Neither Yes/No"]),
    Question(8, "Are you in US House District 1 or 2?", ["District 1", "District 2", "Don't Know"]),
    Question(9, "If you had to choose today, which of the following candidates would you choose to support for House Representative in District 1?", ["Zinke (R)","Tranel (D)", "Lamb (L)", "Don't Know"]),
    Question(10, "At this point in time, do you approve or disapprove of Congressperson Matt Rosendale’s job performance?", ["Approve", "Disapprove", "Neither Approve/Disapprove"]),
    Question(11, "If you had to choose today, which of the following candidates would you choose to support for House Representative in District 2?", ["Rosendale (R)","Ronning (D)", "Rankin (L)", "Buchanan (I)", "Don't Know"]),
    Question(12, "At this point in time, do you approve or disapprove of Senator Steve Daines’ job performance?", ["Approve", "Disapprove", "Neither Approve/Disapprove"]),
    Question(13, "At this point in time, do you approve or disapprove of Senator Jon Tester’s job performance?", ["Approve", "Disapprove", "Neither Approve/Disapprove"]),
    Question(14, "Do you trust your representatives’ ability to govern efficiently and in a non-divisive manner?", ["Trust", "Distrust", "Neither Trust/Distrust"]),
    Question(15, "Do you trust your local police or sheriff’s department?", ["Trust", "Distrust", "Neither Trust/Distrust"]),
    Question(16, "Have you heard of the Indian Education for All law?", ["Yes", "No", "Neither Yes/No"]),
    Question(17, "The Indian Education for All law is based on a Montana constitutional requirement to encourage learning about American Indian culture and history. Do you believe the money from this law is being used effectively to educate the general student body within Montana’s school system?", ["Yes", "No", "Neither Yes/No"]),
    Question(18, "Do you agree or disagree that there is a mental health crisis in Montana?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(19, "Do you agree or disagree that more fun indoor activities could help the depression rate in Montana?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(20, "Do you agree or disagree that businesses in your community are struggling to find employees?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(21, "Do you agree or disagree that current Montana agricultural practices are environmentally sustainable?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(22, "Do you agree or disagree that Montana officials should work to protect public lands?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(23, "Do you agree or disagree with the Supreme Court's decision to overturn Roe v. Wade?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(24, "When it comes to abortion issues, would you consider yourself to be pro-life or pro-choice?", ["Pro-life", "Pro-choice", "Neither Pro-life/Pro-choice"]),
    Question(25, "Do you agree or disagree with the efforts to remove potentially controversial books from public schools?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(26, "Do you agree or disagree that teachers with a clean background check and training should be allowed to carry a gun in the classroom?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(27, "Do you agree or disagree with using the death penalty as punishment for convicted murder?", ["Agree", "Disagree", "Neither Agree/Disagree"]),
    Question(28, "Do you trust mainstream media?", ["Trust", "Distrust", "Neither Trust/Distrust"])
]

# %%
resps_out = {}
for i in range(len(questions)):
    resps_out[i+1] = []

for i in range(len(questions)):
    for s in responses:
        try:
            resp_data = json.loads(s['survey_responses'][str(i+1)])
            resp_val = resp_data['Answer']
            resps_out[i+1].append(resp_val)   
        except Exception as e:
            print("Invalid Format", str(e))
            continue
# Out:
# Invalid Format Unterminated string starting at: line 2 column 18 (char 19)
# Invalid Format Extra data: line 6 column 1 (char 1207)
# Invalid Format Expecting ',' delimiter: line 4 column 1 (char 861)
# Invalid Format Extra data: line 13 column 1 (char 720)
# Invalid Format Unterminated string starting at: line 2 column 18 (char 19)
# Invalid Format Unterminated string starting at: line 9 column 15 (char 906)
# Invalid Format Extra data: line 6 column 1 (char 916)
# Invalid Format Unterminated string starting at: line 2 column 18 (char 19)
# Invalid Format Unterminated string starting at: line 3 column 15 (char 1324)
# Invalid Format 'Answer'
# Invalid Format Unterminated string starting at: line 3 column 15 (char 1309)
# Invalid Format Unterminated string starting at: line 2 column 18 (char 19)
# Invalid Format Expecting property name enclosed in double quotes: line 4 column 1 (char 524)
# Invalid Format Unterminated string starting at: line 5 column 19 (char 1396)
# Invalid Format Unterminated string starting at: line 2 column 1314 (char 1315)
# Invalid Format Unterminated string starting at: line 7 column 9 (char 1214)
# Invalid Format Unterminated string starting at: line 2 column 848 (char 849)
# Invalid Format Unterminated string starting at: line 2 column 731 (char 732)
# Invalid Format Unterminated string starting at: line 9 column 15 (char 1250)
# Invalid Format Unterminated string starting at: line 2 column 18 (char 19)
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'
# Invalid Format '28'

# %%
def count_responses(responses):
    # Count occurrences of each unique value
    counts = {}
    total_responses = len(responses)

    for response in responses:
        if response not in counts:
            counts[response] = 0
        counts[response] += 1

    # Print counts and percentages
    print("Counts of each response:")
    for response, count in counts.items():
        percentage = (count / total_responses) * 100
        print(f"{response}: {count} ({percentage:.2f}%)")

# %%
for i, resp in resps_out.items():
    print(f"Question {i}: {questions[i-1].question}")
    count_responses(resp)
    print()
# Out:
# Question 1: Do you plan to vote in the 2022 midterm election?
# Counts of each response:
# Yes: 343 (100.00%)
#
# Question 2: At this point in time, do you approve or disapprove of President Joe Biden’s performance in office?
# Counts of each response:
# Disapprove: 82 (23.91%)
# Approve: 185 (53.94%)
# Neither Approve/Disapprove: 76 (22.16%)
#
# Question 3: Do you approve or disapprove of Biden’s student loan forgiveness plan?
# Counts of each response:
# Neither Approve/Disapprove: 22 (6.41%)
# Approve: 277 (80.76%)
# Disapprove: 44 (12.83%)
#
# Question 4: At this point in time, do you approve or disapprove of the performance of the US Congress?
# Counts of each response:
# Disapprove: 142 (41.64%)
# Neither Approve/Disapprove: 164 (48.09%)
# Approve: 34 (9.97%)
# At this point in time, I disapprove of the performance of the US Congress.: 1 (0.29%)
#
# Question 5: When electing the United States president, do you think we should amend the Constitution to allow the candidate who receives the most votes to win, or do you think we should keep the current system where the candidate who wins the Electoral College vote wins?
# Counts of each response:
# Keep the current system: 182 (53.22%)
# Neither Amend/Keep: 14 (4.09%)
# Amend the Constitution: 146 (42.69%)
#
# Question 6: At this point in time, do you approve or disapprove of Governor Greg Gianforte’s job performance?
# Counts of each response:
# Approve: 252 (73.47%)
# Neither Approve/Disapprove: 78 (22.74%)
# Disapprove: 13 (3.79%)
#
# Question 7: Gianforte’s administration recently attempted to implement a rule banning transgender people from changing their designated sex status on their birth certificate. Do you think transgender people should be able to change the sex on their birth certificate?
# Counts of each response:
# Yes: 343 (100.00%)
#
# Question 8: Are you in US House District 1 or 2?
# Counts of each response:
# District 1: 188 (54.81%)
# Don't Know: 155 (45.19%)
#
# Question 9: If you had to choose today, which of the following candidates would you choose to support for House Representative in District 1?
# Counts of each response:
# Zinke (R): 160 (47.06%)
# Don't Know: 66 (19.41%)
# I would need to research the candidates and their platforms before making a decision.: 1 (0.29%)
# Tranel (D): 74 (21.76%)
# Undecided: 6 (1.76%)
# I would need to research the candidates' platforms and positions before making a decision.: 1 (0.29%)
# Prefer not to disclose.: 1 (0.29%)
# Tranel: 3 (0.88%)
# I would need to research each candidate's policies and values before making my decision. Therefore, I do not know which candidate I would support at this time.: 1 (0.29%)
# I would need to research the positions of the candidates before making a decision, but I would not support the Republican candidate Zinke.: 1 (0.29%)
# Lamb (L): 16 (4.71%)
# Undecided/Don't Know: 2 (0.59%)
# I would need to do more research on each candidate before making a decision. At this time, I do not have enough information to choose a candidate to support.: 1 (0.29%)
# I would choose between Tranel (D) or Lamb (L), depending on their specific policies and positions.: 1 (0.29%)
# I would choose to support Tranel (D) for House Representative in District 1. After researching each candidate's policies and values, I found that Tranel's platform aligns best with my beliefs and values. Additionally, as a liberal, I tend to vote for Democratic candidates, and Tranel is the Democratic candidate in this race. While Lamb (L) is also a liberal candidate, I found that Tranel's platform better aligns with my specific beliefs and concerns.: 1 (0.29%)
# I would need to research the stances of Zinke (R), Tranel (D), and Lamb (L) on important issues before making a decision on who to support for House Representative in District 1.: 1 (0.29%)
# I would need to research each candidate's platform and voting record before making a decision. At this time, I am undecided.: 1 (0.29%)
# Lamb (L) or Tranel (D): 1 (0.29%)
# I would need to research each candidate's platform and policies before making a decision.: 1 (0.29%)
# I would choose Zinke (R) based on my political leanings and geographic location.: 1 (0.29%)
#
# Question 10: At this point in time, do you approve or disapprove of Congressperson Matt Rosendale’s job performance?
# Counts of each response:
# Approve: 198 (57.73%)
# Neither Approve/Disapprove: 140 (40.82%)
# Disapprove: 5 (1.46%)
#
# Question 11: If you had to choose today, which of the following candidates would you choose to support for House Representative in District 2?
# Counts of each response:
# Rosendale (R): 165 (48.10%)
# Don't Know: 70 (20.41%)
# Ronning (D): 92 (26.82%)
# I would support the Democratic candidate Ronning, as they align more closely with my left-leaning political views.: 1 (0.29%)
# I would need to do more research on the candidates and their policies before making a decision on who to support for House Representative in District 2.: 1 (0.29%)
# I would need to do more research on the candidates' policies and values before making a decision.: 1 (0.29%)
# Undecided: 2 (0.58%)
# Undecided/Don't Know: 3 (0.87%)
# I would need to research the candidates and their platforms before making a final decision. At this time, I do not have a preference for any particular candidate.: 1 (0.29%)
# I would need to research each candidate's platform and policies before making a decision. I would also consider their track record and experience in public service. Additionally, as a resident of District 2, I would want to choose a candidate who has a strong understanding of the issues facing our community and has a plan to address them. Therefore, I don't know which candidate I would support at this time.: 1 (0.29%)
# I would support Ronning (D) for House Representative in District 2.: 1 (0.29%)
# I would research each candidate's stance on important issues that are relevant to me and make an informed decision based on that. If after researching all the candidates, I do not feel confident in making a decision, I would choose the 'Don't Know' option.: 1 (0.29%)
# I would need to research each candidate's platform and values before making a decision.: 1 (0.29%)
# I would need to research the policies and platforms of each candidate before making a decision on who to support for House Representative in District 2. I cannot provide an answer at this time.: 1 (0.29%)
# I would need to review the platforms and positions of all the candidates before making a final decision.: 1 (0.29%)
# I would choose Ronning (D) based on their positions on the issues that are important to me and their experience in public service.: 1 (0.29%)
#
# Question 12: At this point in time, do you approve or disapprove of Senator Steve Daines’ job performance?
# Counts of each response:
# Approve: 246 (71.72%)
# Neither Approve/Disapprove: 83 (24.20%)
# Disapprove: 14 (4.08%)
#
# Question 13: At this point in time, do you approve or disapprove of Senator Jon Tester’s job performance?
# Counts of each response:
# Neither Approve/Disapprove: 129 (37.61%)
# Approve: 191 (55.69%)
# Disapprove: 23 (6.71%)
#
# Question 14: Do you trust your representatives’ ability to govern efficiently and in a non-divisive manner?
# Counts of each response:
# Trust: 90 (26.32%)
# Neither Trust/Distrust: 231 (67.54%)
# Distrust: 21 (6.14%)
#
# Question 15: Do you trust your local police or sheriff’s department?
# Counts of each response:
# Trust: 124 (36.26%)
# Neither Trust/Distrust: 210 (61.40%)
# I generally trust my local police or sheriffs department, but my trust would depend on my personal experiences with them.: 1 (0.29%)
# I generally trust my local police and sheriff's department, as I believe in the importance of law and order. However, my trust would depend on my personal experiences with them.: 1 (0.29%)
# It depends on my personal experiences with them. If I have had positive interactions with them in the past and feel that they are doing a good job of keeping my community safe, then I would trust them. On the other hand, if I have had negative experiences or feel that they are not doing a good job, then I would distrust them. If I have not had any personal experiences with them, then I would neither trust nor distrust them.: 1 (0.29%)
# Distrust: 4 (1.17%)
# It depends on my personal experiences with them.: 1 (0.29%)
#
# Question 16: Have you heard of the Indian Education for All law?
# Counts of each response:
# Yes: 284 (82.80%)
# No: 14 (4.08%)
# Neither Yes/No: 45 (13.12%)
#
# Question 17: The Indian Education for All law is based on a Montana constitutional requirement to encourage learning about American Indian culture and history. Do you believe the money from this law is being used effectively to educate the general student body within Montana’s school system?
# Counts of each response:
# No: 3 (0.88%)
# Yes: 157 (46.18%)
# Neither Yes/No: 180 (52.94%)
#
# Question 18: Do you agree or disagree that there is a mental health crisis in Montana?
# Counts of each response:
# Agree: 340 (99.13%)
# Neither Agree/Disagree: 3 (0.87%)
#
# Question 19: Do you agree or disagree that more fun indoor activities could help the depression rate in Montana?
# Counts of each response:
# Agree: 337 (98.54%)
# Neither Agree/Disagree: 4 (1.17%)
# Disagree: 1 (0.29%)
#
# Question 20: Do you agree or disagree that businesses in your community are struggling to find employees?
# Counts of each response:
# Agree: 297 (86.84%)
# Neither Agree/Disagree: 40 (11.70%)
# Disagree: 4 (1.17%)
# Somewhat Agree: 1 (0.29%)
#
# Question 21: Do you agree or disagree that current Montana agricultural practices are environmentally sustainable?
# Counts of each response:
# Neither Agree/Disagree: 122 (35.67%)
# Disagree: 119 (34.80%)
# Agree: 101 (29.53%)
#
# Question 22: Do you agree or disagree that Montana officials should work to protect public lands?
# Counts of each response:
# Agree: 343 (100.00%)
#
# Question 23: Do you agree or disagree with the Supreme Court's decision to overturn Roe v. Wade?
# Counts of each response:
# Agree: 154 (44.90%)
# Disagree: 175 (51.02%)
# Neither Agree/Disagree: 14 (4.08%)
#
# Question 24: When it comes to abortion issues, would you consider yourself to be pro-life or pro-choice?
# Counts of each response:
# Pro-life: 219 (63.85%)
# Neither Pro-life/Pro-choice: 14 (4.08%)
# Pro-choice: 107 (31.20%)
# Pro-life with exceptions: 1 (0.29%)
# Pro-choice with some limitations: 1 (0.29%)
# Pro-life with some exceptions.: 1 (0.29%)
#
# Question 25: Do you agree or disagree with the efforts to remove potentially controversial books from public schools?
# Counts of each response:
# Disagree: 329 (96.20%)
# Neither Agree/Disagree: 5 (1.46%)
# Agree: 8 (2.34%)
#
# Question 26: Do you agree or disagree that teachers with a clean background check and training should be allowed to carry a gun in the classroom?
# Counts of each response:
# Agree: 147 (43.36%)
# Disagree: 156 (46.02%)
# Neither Agree/Disagree: 36 (10.62%)
#
# Question 27: Do you agree or disagree with using the death penalty as punishment for convicted murder?
# Counts of each response:
# Agree: 171 (50.00%)
# Disagree: 126 (36.84%)
# Neither Agree/Disagree: 45 (13.16%)
#
# Question 28: Do you trust mainstream media?
# Counts of each response:
