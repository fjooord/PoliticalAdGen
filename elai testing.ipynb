# %%
import requests
import json
import Utils.Chat_GPT_Funcs as GPT
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

# %% [markdown]
# # Set ELAI API key

# %%
ELAI_API = "gvGKAhdmh1OiEcZ2KY3qZIciRA90dOL7"

# %% [markdown]
# # Classes for holding templates for easy use

# %%
class VideoTemplate:
    def __init__(self, template_id, slide_templates=None):
        self.template_id = template_id
        self.slide_templates = slide_templates if slide_templates is not None else []

    def add_slide_template(self, slide_template):
        self.slide_templates.append(slide_template)

    def remove_slide_template(self, slide_template):
        if slide_template in self.slide_templates:
            self.slide_templates.remove(slide_template)

    def __str__(self):
        return f"VideoTemplate(id={self.template_id}, slides={self.slide_templates})"

class SlideTemplate:
    def __init__(self, slide_template_id, hasHeader=False, hasSubheader=False, hasList=False, hasImage=False):
        self.slide_template_id = slide_template_id
        self.hasHeader = hasHeader
        self.hasSubheader = hasSubheader
        self.hasList = hasList
        self.hasImage = hasImage

    def __str__(self):
        return f"SlideTemplate(id={self.slide_template_id}, hasHeader={self.hasHeader}, hasSubheader={self.hasSubheader}, hasList={self.hasList}, hasImage={self.hasImage})"

# %% [markdown]
# # Create the slide templates based on the template were using

# %%
#template_id = "64764303f8070631abe49a1b"
template_id = "64760a08f8070631abe3f9ec"
slide_ids = [1401745240374, 570084307296, 108289632351, 777652954713]

# %%
slide_templates = []

for i in range(4):
    slide_id = slide_ids[i]
    if i == 0:
        new_slide = SlideTemplate(slide_id, hasHeader=True, hasSubheader=True)
        
    elif i == 1:
        new_slide = SlideTemplate(slide_id, hasList=True)
        
    elif i == 2:
        new_slide = SlideTemplate(slide_id, hasHeader=True, hasSubheader=True, hasImage=True)
    
    elif i == 3:
        new_slide = SlideTemplate(slide_id, hasHeader=True, hasImage=True)

    slide_templates.append(new_slide)
    
video_template = VideoTemplate(template_id, slide_templates)

# %% [markdown]
# # Generate the Story

# %%
def make_empty_story(template_id):
    url = "https://apis.elai.io/api/v1/story/text"

    payload = {
        "templateId": f"{template_id}",
        "from": ""
    }
    headers = {
        "accept": "application/json",
        "content-type": "application/json",
        "Authorization": "Bearer gvGKAhdmh1OiEcZ2KY3qZIciRA90dOL7"
    }

    response = requests.post(url, json=payload, headers=headers)

    print(response.text)
    return response.text

# %%
def make_vid_from_template(template_id):
    url = "https://apis.elai.io/api/v1/videos/byTemplate"

    payload = {"templateId": f"{template_id}"}
    headers = {
        "accept": "application/json",
        "content-type": "application/json",
        "Authorization": "Bearer gvGKAhdmh1OiEcZ2KY3qZIciRA90dOL7"
    }

    response = requests.post(url, json=payload, headers=headers)

    print(response.text)
    return response.text

# %%
test = make_empty_story(template_id)
# Out:
# {"name":"Storyboard Draft","type":"story","data":{"resolution":"FullHD","musicName":"Driving Ambition","musicUrl":"https://elai-media.s3.eu-west-2.amazonaws.com/music/mixkit-driving-ambition-32.mp3","musicVolume":0.12,"musicShift":0,"subtitlesUrl":"https://elai-media.s3.eu-west-2.amazonaws.com/production/videos/6410bb5d93ae4058e6e8f3e0/subtitles.srt","format":"9_16","templateType":"text-to-video"},"slides":[{"id":1278900196192,"speech":"","avatar":{"_id":"6426982cd78b5bdaad49b022","id":"kira.doctor","name":"Doctor","type":null,"version":2,"status":2,"gender":"female","intro":"https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/kira_intro.mp4","tilt":{"left":0.05},"thumbnail":"https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/doctor/kira_doctor.jpg","canvas":"https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/doctor/kira_doctor.png"},"voiceType":"text","animation":"fade_in","newlyAdded":false,"status":"story","transition":"fadewhite","screenshot":"https://el
# ...

# %%
test_json = """
{
  "id": 1125874895785,
  "speech": "",
  "avatar": {
    "id": "chad.business3",
    "name": "Business",
    "gender": "male",
    "gif": "https://elai-media.s3.eu-west-2.amazonaws.com/avatars/chad_business_3.gif",
    "thumbnail": "https://elai-media.s3.eu-west-2.amazonaws.com/avatars/chad_business_3.jpg",
    "canvas": "https://elai-media.s3.eu-west-2.amazonaws.com/avatars/chad_business_3.png",
    "tilt": {
      "left": 0.03
    }
  },
  "language": "English",
  "voiceType": "text",
  "animation": null,
  "transition": "wiperight",
  "status": "story",
  "story": {}
}
"""

# %%
headers = [
  "SECURE OUR BORDERS",
  "BUILD THE WALL",
  "A STRONGER SOUTH GEORGIA"
]

subheaders = [
  "Les Lascari stands for strong immigration policies",
  "Les Lascari supports Trump's vision",
  "Vote Les Lascari for Congress"
]

speeches = [
  "In South Georgia, we know the importance of SECURITY. That's why Les Lascari will CRACK DOWN on illegal immigration.",
  "Les Lascari is committed to BUILDING Trump's wall - protecting our COMMUNITIES and our VALUES.",
  "Stand with Les Lascari - for a safer, stronger South Georgia. He'll FIGHT for YOU in Congress."
]

cut_scenes = [
  "Aerial shot of the border with dramatic music",
  "Footage of construction workers and border patrol agents",
  "Les Lascari shaking hands with constituents"
]

# %%
im_link = "https://pixelartmaker-data-78746291193.nyc3.digitaloceanspaces.com/image/46a51b87f95de4c.png"
im_link = "https://talesfortots.s3.amazonaws.com/1682533332490x138489597064642560_page_image_1.jpg"

# %%
def create_image_dict(url):
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))

    # Display the image for debugging
#     plt.imshow(img)
#     plt.show()

    image_dict = {
        "image": {
            "src": url,
            "alt": "main",
            "size": {
                "width": img.width,
                "height": img.height,
                "type": img.format.lower(),
                "mime": f"image/{img.format.lower()}",
                "wUnits": "px",
                "hUnits": "px",
                "length": len(response.content),
                "url": url,
            },
            "orientation": "landscape"
        }
    }

    return image_dict

# %%
image_base = create_image_dict(im_link)

# %%
image_base
# Out:
# {'image': {'src': 'https://talesfortots.s3.amazonaws.com/1682533332490x138489597064642560_page_image_1.jpg',
#   'alt': 'main',
#   'size': {'width': 1200,
#    'height': 1600,
#    'type': 'jpeg',
#    'mime': 'image/jpeg',
#    'wUnits': 'px',
#    'hUnits': 'px',
#    'length': 318723,
#    'url': 'https://talesfortots.s3.amazonaws.com/1682533332490x138489597064642560_page_image_1.jpg'},
#   'orientation': 'landscape'}}

# %%
import random


def make_slide_json(slide_template_id, speech, header=None, subheader=None, List=None, image_url=None):
    
    base_slide = json.loads(test_json)
    base_slide['id'] = random.randint(1, 100000000000)
    base_slide['speech'] = speech
    story_dict = {
        "templateSlideId": slide_template_id,
    }
    
    if header is not None:
        story_dict['header'] = header
        
    if subheader is not None:
        story_dict['subHeader'] = subheader
        
    if List is not None:
        story_dict['list'] = List
        
    if image_url is not None:
        story_dict['image'] = image_base
        
    base_slide['story'] = story_dict
        
    return base_slide

# %%
slides = []
for i in range(3):
    slide_id = slide_ids[i]
    if i == 0:
        new_slide = make_slide_json(slide_id, speeches[i], header=headers[i],subheader=subheaders[i])
        
    elif i == 1:
        my_list = ["words words words", "punchline", "i have a bucket", "it has a hole in it"]
        new_slide = make_slide_json(slide_id, speeches[i], List=my_list)
        
    elif i == 2:
        new_slide = make_slide_json(slide_id, speeches[i], header=headers[i],subheader=subheaders[i], image_url="asdf")
    
    elif i == 3:
        new_slide = make_slide_json(slide_id, speeches[i], header=headers[i], img_url="asdf")
    
    else:
        continue
        
    slides.append(new_slide)

# %%
slides[2]
# Out:
# {'id': 7954916891,
#  'speech': "Stand with Les Lascari - for a safer, stronger South Georgia. He'll FIGHT for YOU in Congress.",
#  'avatar': {'id': 'chad.business3',
#   'name': 'Business',
#   'gender': 'male',
#   'gif': 'https://elai-media.s3.eu-west-2.amazonaws.com/avatars/chad_business_3.gif',
#   'thumbnail': 'https://elai-media.s3.eu-west-2.amazonaws.com/avatars/chad_business_3.jpg',
#   'canvas': 'https://elai-media.s3.eu-west-2.amazonaws.com/avatars/chad_business_3.png',
#   'tilt': {'left': 0.03}},
#  'language': 'English',
#  'voiceType': 'text',
#  'animation': None,
#  'transition': 'wiperight',
#  'status': 'story',
#  'story': {'templateSlideId': 108289632351,
#   'header': 'A STRONGER SOUTH GEORGIA',
#   'subHeader': 'Vote Les Lascari for Congress',
#   'image': {'image': {'src': 'https://talesfortots.s3.amazonaws.com/1682533332490x138489597064642560_page_image_1.jpg',
#     'alt': 'main',
#     'size': {'width': 1200,
#      'height': 1600,
#      'type': 'jpeg',
# ...

# %%
vid_id = "647787884ad20315b6bf0e07"

# %%
def update_slides(video_id, slides):
    url = f"https://apis.elai.io/api/v1/videos/{vid_id}"

    payload = {
        "slides": slides,
        "public": False,
    }
    
    headers = {
        "accept": "application/json",
        "content-type": "application/json",
        "Authorization": "Bearer gvGKAhdmh1OiEcZ2KY3qZIciRA90dOL7"
    }

    response = requests.patch(url, json=payload, headers=headers)

    print(response.text)
    return response.text

# %%
updated_json = update_slides(vid_id, slides)
# Out:
# {"_id":"647787884ad20315b6bf0e07","name":"Storyboard Draft","type":"story","data":{"resolution":"FullHD","musicName":"Driving Ambition","musicUrl":"https://elai-media.s3.eu-west-2.amazonaws.com/music/mixkit-driving-ambition-32.mp3","musicVolume":0.12,"musicShift":0,"subtitlesUrl":"https://elai-media.s3.eu-west-2.amazonaws.com/production/videos/647787884ad20315b6bf0e07/subtitles.srt","format":"9_16","templateType":"text-to-video"},"slides":[{"id":88501499691,"speech":"In South Georgia, we know the importance of SECURITY. That's why Les Lascari will CRACK DOWN on illegal immigration.","avatar":{"id":"chad.business3","name":"Business","gender":"male","gif":"https://elai-media.s3.eu-west-2.amazonaws.com/avatars/chad_business_3.gif","thumbnail":"https://elai-media.s3.eu-west-2.amazonaws.com/avatars/chad_business_3.jpg","canvas":"https://elai-media.s3.eu-west-2.amazonaws.com/avatars/chad_business_3.png","tilt":{"left":0.03}},"language":"English","voiceType":"text","animation":null,"transit
# ...

# %%
json.loads(updated_json)
# Out:
# {'_id': '647787884ad20315b6bf0e07',
#  'name': 'Storyboard Draft',
#  'type': 'story',
#  'data': {'resolution': 'FullHD',
#   'musicName': 'Driving Ambition',
#   'musicUrl': 'https://elai-media.s3.eu-west-2.amazonaws.com/music/mixkit-driving-ambition-32.mp3',
#   'musicVolume': 0.12,
#   'musicShift': 0,
#   'subtitlesUrl': 'https://elai-media.s3.eu-west-2.amazonaws.com/production/videos/647787884ad20315b6bf0e07/subtitles.srt',
#   'format': '9_16',
#   'templateType': 'text-to-video'},
#  'slides': [{'id': 19148696210,
#    'speech': "In South Georgia, we know the importance of SECURITY. That's why Les Lascari will CRACK DOWN on illegal immigration.",
#    'avatar': {'id': 'chad.business3',
#     'name': 'Business',
#     'gender': 'male',
#     'gif': 'https://elai-media.s3.eu-west-2.amazonaws.com/avatars/chad_business_3.gif',
#     'thumbnail': 'https://elai-media.s3.eu-west-2.amazonaws.com/avatars/chad_business_3.jpg',
# ...

# %%
vid_json = json.loads(test)

# %%
for s in vid_json['slides']:
    for o in s['canvas']['objects']:
        if o['type'] == 'i-text':
            print(o)
            break
    break
# Out:
# {'type': 'i-text', 'version': '4.4.0', 'originX': 'left', 'originY': 'top', 'left': 250.83, 'top': 81.8, 'width': 136.8, 'height': 45.2, 'fill': '#14709b', 'stroke': None, 'strokeWidth': 1, 'strokeDashArray': None, 'strokeLineCap': 'butt', 'strokeDashOffset': 0, 'strokeLineJoin': 'miter', 'strokeUniform': False, 'strokeMiterLimit': 4, 'scaleX': 1, 'scaleY': 1, 'angle': 0, 'flipX': False, 'flipY': False, 'opacity': 1, 'shadow': None, 'visible': True, 'backgroundColor': '', 'fillRule': 'nonzero', 'paintFirst': 'fill', 'globalCompositeOperation': 'source-over', 'skewX': 0, 'skewY': 0, 'text': 'Cortexi', 'fontSize': '40', 'fontWeight': 'bold', 'fontFamily': 'Josefin Sans', 'fontStyle': 'normal', 'lineHeight': 1.16, 'underline': False, 'overline': False, 'linethrough': False, 'textAlign': 'left', 'textBackgroundColor': '', 'charSpacing': 0, 'path': None, 'id': 42240358997}

# %%
text = GPT.open_file('test_load.txt')

# %%
print(text)
# Out:
# Vote Les Lascari
#
# SECURE OUR BORDERS
# In South Georgia, we know the importance of SECURITY. That's why Les Lascari will CRACK DOWN on illegal immigration.
#
# BUILD THE WALL
# Les Lascari is committed to BUILDING Trump's wall - protecting our COMMUNITIES and our VALUES.
#
# A STRONGER SOUTH GEORGIA
# Stand with Les Lascari - for a safer, stronger South Georgia. He'll FIGHT for YOU in Congress.

# %% [markdown]
# # Get video ID from template

# %%
vid_resp = json.loads(response.text)
vid_id = vid_resp['_id']
print(vid_id)
# Out:
# 64763a88399dc9d6d626aa84

# %%
url = f"https://apis.elai.io/api/v1/story/generate-slides/{vid_id}"

payload = {"fixWithGpt": True}
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "Authorization": "Bearer gvGKAhdmh1OiEcZ2KY3qZIciRA90dOL7"
}

response = requests.post(url, json=payload, headers=headers)

print(response.text)
# Out:
# {"_id":"64763a88399dc9d6d626aa84","name":"Vote Les Lascari","type":"story","data":{"skipEmails":false,"subtitlesEnabled":false,"format":"9_16","musicUrl":"https://elai-media.s3.eu-west-2.amazonaws.com/music/mixkit-driving-ambition-32.mp3","musicVolume":0.17,"resolution":"FullHD","subtitlesUrl":"https://elai-media.s3.eu-west-2.amazonaws.com/production/videos/64763a88399dc9d6d626aa84/subtitles.srt"},"slides":[{"id":1154713743643,"speech":"In South Georgia, we know the importance of SECURITY. That's why Les Lascari will CRACK DOWN on illegal immigration.","avatar":{"_id":"6426982cd78b5bdaad49b022","id":"kira.doctor","name":"Doctor","type":null,"version":2,"status":2,"gender":"female","intro":"https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/kira_intro.mp4","tilt":{"left":0.05},"thumbnail":"https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/doctor/kira_doctor.jpg","canvas":"https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/doctor/kira_doctor.png"},"language"
# ...

# %%
vid_json = json.loads(response.text)

# %%
vid_json['slides']
# Out:
# [{'id': 1154713743643,
#   'speech': "In South Georgia, we know the importance of SECURITY. That's why Les Lascari will CRACK DOWN on illegal immigration.",
#   'avatar': {'_id': '6426982cd78b5bdaad49b022',
#    'id': 'kira.doctor',
#    'name': 'Doctor',
#    'type': None,
#    'version': 2,
#    'status': 2,
#    'gender': 'female',
#    'intro': 'https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/kira_intro.mp4',
#    'tilt': {'left': 0.05},
#    'thumbnail': 'https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/doctor/kira_doctor.jpg',
#    'canvas': 'https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/doctor/kira_doctor.png'},
#   'language': 'English',
#   'voiceType': 'text',
#   'animation': 'fade_in',
#   'newlyAdded': False,
#   'status': 'ready',
#   'approxDuration': 7.25,
#   'transition': 'fadewhite',
#   'story': {'templateSlideId': 1401745240374,
#    'header': 'SECURE OUR BORDERS',
# ...

# %%
url = f"https://apis.elai.io/api/v1/videos/{vid_id}"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer gvGKAhdmh1OiEcZ2KY3qZIciRA90dOL7"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"_id":"64763a88399dc9d6d626aa84","name":"Vote Les Lascari","type":"story","data":{"skipEmails":false,"subtitlesEnabled":false,"format":"9_16","musicUrl":"https://elai-media.s3.eu-west-2.amazonaws.com/music/mixkit-driving-ambition-32.mp3","musicVolume":0.17,"resolution":"FullHD","subtitlesUrl":"https://elai-media.s3.eu-west-2.amazonaws.com/production/videos/64763a88399dc9d6d626aa84/subtitles.srt"},"slides":[{"id":1154713743643,"speech":"In South Georgia, we know the importance of SECURITY. That's why Les Lascari will CRACK DOWN on illegal immigration.","avatar":{"_id":"6426982cd78b5bdaad49b022","id":"kira.doctor","name":"Doctor","type":null,"version":2,"status":2,"gender":"female","intro":"https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/kira_intro.mp4","tilt":{"left":0.05},"thumbnail":"https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/doctor/kira_doctor.jpg","canvas":"https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/doctor/kira_doctor.png"},"language"
# ...

# %%
vid_json = json.loads(response.text)

# %%
vid_json['slides'][1]
# Out:
# {'id': 82619022481,
#  'speech': "Les Lascari is committed to BUILDING Trump's wall - protecting our COMMUNITIES and our VALUES.",
#  'avatar': {'_id': '6426982cd78b5bdaad49b022',
#   'id': 'kira.doctor',
#   'name': 'Doctor',
#   'type': None,
#   'version': 2,
#   'status': 2,
#   'gender': 'female',
#   'intro': 'https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/kira_intro.mp4',
#   'tilt': {'left': 0.05},
#   'thumbnail': 'https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/doctor/kira_doctor.jpg',
#   'canvas': 'https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/doctor/kira_doctor.png'},
#  'language': 'English',
#  'voiceType': 'text',
#  'animation': 'fade_in',
#  'newlyAdded': False,
#  'status': 'ready',
#  'approxDuration': 5.875,
#  'transition': 'fadewhite',
#  'story': {'templateSlideId': 108289632351,
#   'header': 'BUILD THE WALL',
#   'subHeader': "Les Lascari supports Trump's vision",
# ...

# %%
slides = vid_json['slides']

# %%
s_heads = ['Les Lascari stands for strong immigration policies', "Les Lascari supports Trump's vision", "Vote Les Lascari for Congress"]

# %%
vid_id
# Out:
# '64763a88399dc9d6d626aa84'

# %%
for i in range(len(slides)):
    #slide['speech'] = 'I have been updated'
    
    if slides[i]['story'].keys().__contains__('subHeader'):
        slides[i]['story']['subHeader'] = s_heads[i]
    slide['status'] = 'edited'

# %%
url = f"https://apis.elai.io/api/v1/videos/{vid_id}"

payload = {
    "slides": slides,
    "public": False,
    "data": {
        "skipEmails": False,
        "subtitlesEnabled": False,
        "format": "9_16",
        "musicUrl": "https://elai-media.s3.eu-west-2.amazonaws.com/music/mixkit-driving-ambition-32.mp3",
        "musicVolume": 0.17,
        "resolution": "FullHD"
    }
}
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "Authorization": "Bearer gvGKAhdmh1OiEcZ2KY3qZIciRA90dOL7"
}

response = requests.patch(url, json=payload, headers=headers)

print(response.text)
# Out:
# {"_id":"64763a88399dc9d6d626aa84","name":"Vote Les Lascari","type":"story","data":{"skipEmails":false,"subtitlesEnabled":false,"format":"9_16","musicUrl":"https://elai-media.s3.eu-west-2.amazonaws.com/music/mixkit-driving-ambition-32.mp3","musicVolume":0.17,"resolution":"FullHD"},"slides":[{"id":1154713743643,"speech":"In South Georgia, we know the importance of SECURITY. That's why Les Lascari will CRACK DOWN on illegal immigration.","avatar":{"_id":"6426982cd78b5bdaad49b022","id":"kira.doctor","name":"Doctor","type":null,"version":2,"status":2,"gender":"female","intro":"https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/kira_intro.mp4","tilt":{"left":0.05},"thumbnail":"https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/doctor/kira_doctor.jpg","canvas":"https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/doctor/kira_doctor.png"},"language":"English","voiceType":"text","animation":"fade_in","newlyAdded":false,"status":"ready","approxDuration":7.25,"transitio
# ...

# %%
url = f"https://apis.elai.io/api/v1/story/generate-slides/{vid_id}"

payload = {"fixWithGpt": True}
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "Authorization": "Bearer gvGKAhdmh1OiEcZ2KY3qZIciRA90dOL7"
}

response = requests.post(url, json=payload, headers=headers)

print(response.text)
# Out:
# {"_id":"64763a88399dc9d6d626aa84","name":"Vote Les Lascari","type":"story","data":{"skipEmails":false,"subtitlesEnabled":false,"format":"9_16","musicUrl":"https://elai-media.s3.eu-west-2.amazonaws.com/music/mixkit-driving-ambition-32.mp3","musicVolume":0.17,"resolution":"FullHD"},"slides":[{"id":1154713743643,"speech":"In South Georgia, we know the importance of SECURITY. That's why Les Lascari will CRACK DOWN on illegal immigration.","avatar":{"_id":"6426982cd78b5bdaad49b022","id":"kira.doctor","name":"Doctor","type":null,"version":2,"status":2,"gender":"female","intro":"https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/kira_intro.mp4","tilt":{"left":0.05},"thumbnail":"https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/doctor/kira_doctor.jpg","canvas":"https://elai-avatars.s3.us-east-2.amazonaws.com/common/kira/doctor/kira_doctor.png"},"language":"English","voiceType":"text","animation":"fade_in","newlyAdded":false,"status":"ready","approxDuration":7.25,"transitio
# ...
